# %%
import pandas as pd 
data=pd.read_csv(r"C:\Users\ashat\Downloads\kuttu ma kuttu.csv")
(data)
# Out:
#             Date     CO  Ozone    NO    NO2    NOX   NH3    SO2  PM2.5   PM10  \
# 0     01-01-2024   0.81  12.00  5.70  11.60  17.40  8.80   6.60  31.00  59.00
# 1     02-01-2024   0.66  13.40  5.80  11.60  17.50  8.90   8.90  39.00  64.00
# 2     03-01-2024   0.55  16.90  5.80  11.50  17.30  8.80  10.30  34.00  61.00
# 3     04-01-2024   0.83  13.70  5.80  11.60  17.40  8.80   9.20  35.00  60.00
# 4     05-01-2024   0.50  14.80  5.70  11.50  17.20  8.80   8.40  21.00  37.00
# ...          ...    ...    ...   ...    ...    ...   ...    ...    ...    ...
# 2401  27-12-2023  56.28  23.96  5.97   0.56   2.81  5.04   7.51   2.19  32.20
# 2402  28-12-2023  54.96  23.37  5.05   0.84   2.75  5.00   7.51   2.21  32.05
# 2403  29-12-2023  56.11  23.89  5.71   1.07   2.80  4.95   7.51   2.22  32.05
# 2404  30-12-2023  55.25  23.50  6.07   0.85   2.76  5.03   7.58   2.23  32.18
# 2405  31-12-2023  55.40  23.57  5.99   0.66   2.77  4.94   7.53   2.21  32.12
#
#        AQI
# 0     59.0
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Date     0
# CO       0
# Ozone    0
# NO       0
# NO2      0
# NOX      0
# NH3      0
# SO2      0
# PM2.5    0
# PM10     0
# AQI      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le2 = LabelEncoder()
data['CO'] = le2.fit_transform(data['CO'])
data
# Out:
#             Date   CO  Ozone    NO    NO2    NOX   NH3    SO2  PM2.5   PM10  \
# 0     01-01-2024  114  12.00  5.70  11.60  17.40  8.80   6.60  31.00  59.00
# 1     02-01-2024   90  13.40  5.80  11.60  17.50  8.90   8.90  39.00  64.00
# 2     03-01-2024   67  16.90  5.80  11.50  17.30  8.80  10.30  34.00  61.00
# 3     04-01-2024  116  13.70  5.80  11.60  17.40  8.80   9.20  35.00  60.00
# 4     05-01-2024   56  14.80  5.70  11.50  17.20  8.80   8.40  21.00  37.00
# ...          ...  ...    ...   ...    ...    ...   ...    ...    ...    ...
# 2401  27-12-2023  754  23.96  5.97   0.56   2.81  5.04   7.51   2.19  32.20
# 2402  28-12-2023  693  23.37  5.05   0.84   2.75  5.00   7.51   2.21  32.05
# 2403  29-12-2023  749  23.89  5.71   1.07   2.80  4.95   7.51   2.22  32.05
# 2404  30-12-2023  703  23.50  6.07   0.85   2.76  5.03   7.58   2.23  32.18
# 2405  31-12-2023  712  23.57  5.99   0.66   2.77  4.94   7.53   2.21  32.12
#
#        AQI
# 0     59.0
# 1     65.0
# 2     61.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le3 = LabelEncoder()
data['Ozone'] = le3.fit_transform(data['Ozone'])
data
# Out:
#             Date   CO  Ozone    NO    NO2    NOX   NH3    SO2  PM2.5   PM10  \
# 0     01-01-2024  114    136  5.70  11.60  17.40  8.80   6.60  31.00  59.00
# 1     02-01-2024   90    202  5.80  11.60  17.50  8.90   8.90  39.00  64.00
# 2     03-01-2024   67    385  5.80  11.50  17.30  8.80  10.30  34.00  61.00
# 3     04-01-2024  116    218  5.80  11.60  17.40  8.80   9.20  35.00  60.00
# 4     05-01-2024   56    269  5.70  11.50  17.20  8.80   8.40  21.00  37.00
# ...          ...  ...    ...   ...    ...    ...   ...    ...    ...    ...
# 2401  27-12-2023  754    729  5.97   0.56   2.81  5.04   7.51   2.19  32.20
# 2402  28-12-2023  693    689  5.05   0.84   2.75  5.00   7.51   2.21  32.05
# 2403  29-12-2023  749    724  5.71   1.07   2.80  4.95   7.51   2.22  32.05
# 2404  30-12-2023  703    698  6.07   0.85   2.76  5.03   7.58   2.23  32.18
# 2405  31-12-2023  712    703  5.99   0.66   2.77  4.94   7.53   2.21  32.12
#
#        AQI
# 0     59.0
# 1     65.0
# 2     61.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le4 = LabelEncoder()
data['NO'] = le4.fit_transform(data['NO'])
data
# Out:
#             Date   CO  Ozone   NO    NO2    NOX   NH3    SO2  PM2.5   PM10  \
# 0     01-01-2024  114    136  495  11.60  17.40  8.80   6.60  31.00  59.00
# 1     02-01-2024   90    202  504  11.60  17.50  8.90   8.90  39.00  64.00
# 2     03-01-2024   67    385  504  11.50  17.30  8.80  10.30  34.00  61.00
# 3     04-01-2024  116    218  504  11.60  17.40  8.80   9.20  35.00  60.00
# 4     05-01-2024   56    269  495  11.50  17.20  8.80   8.40  21.00  37.00
# ...          ...  ...    ...  ...    ...    ...   ...    ...    ...    ...
# 2401  27-12-2023  754    729  517   0.56   2.81  5.04   7.51   2.19  32.20
# 2402  28-12-2023  693    689  456   0.84   2.75  5.00   7.51   2.21  32.05
# 2403  29-12-2023  749    724  496   1.07   2.80  4.95   7.51   2.22  32.05
# 2404  30-12-2023  703    698  523   0.85   2.76  5.03   7.58   2.23  32.18
# 2405  31-12-2023  712    703  519   0.66   2.77  4.94   7.53   2.21  32.12
#
#        AQI
# 0     59.0
# 1     65.0
# 2     61.0
# 3     60.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le5 = LabelEncoder()
data['NO2'] = le5.fit_transform(data['NO2'])
data
# Out:
#             Date   CO  Ozone   NO  NO2    NOX   NH3    SO2  PM2.5   PM10   AQI
# 0     01-01-2024  114    136  495  267  17.40  8.80   6.60  31.00  59.00  59.0
# 1     02-01-2024   90    202  504  267  17.50  8.90   8.90  39.00  64.00  65.0
# 2     03-01-2024   67    385  504  258  17.30  8.80  10.30  34.00  61.00  61.0
# 3     04-01-2024  116    218  504  267  17.40  8.80   9.20  35.00  60.00  60.0
# 4     05-01-2024   56    269  495  258  17.20  8.80   8.40  21.00  37.00  37.0
# ...          ...  ...    ...  ...  ...    ...   ...    ...    ...    ...   ...
# 2401  27-12-2023  754    729  517   55   2.81  5.04   7.51   2.19  32.20   0.5
# 2402  28-12-2023  693    689  456   83   2.75  5.00   7.51   2.21  32.05   0.5
# 2403  29-12-2023  749    724  496  106   2.80  4.95   7.51   2.22  32.05   0.5
# 2404  30-12-2023  703    698  523   84   2.76  5.03   7.58   2.23  32.18   0.5
# 2405  31-12-2023  712    703  519   65   2.77  4.94   7.53   2.21  32.12   0.5
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le6 = LabelEncoder()
data['NOX'] = le6.fit_transform(data['NOX'])
data
# Out:
#             Date   CO  Ozone   NO  NO2  NOX   NH3    SO2  PM2.5   PM10   AQI
# 0     01-01-2024  114    136  495  267  558  8.80   6.60  31.00  59.00  59.0
# 1     02-01-2024   90    202  504  267  568  8.90   8.90  39.00  64.00  65.0
# 2     03-01-2024   67    385  504  258  547  8.80  10.30  34.00  61.00  61.0
# 3     04-01-2024  116    218  504  267  558  8.80   9.20  35.00  60.00  60.0
# 4     05-01-2024   56    269  495  258  540  8.80   8.40  21.00  37.00  37.0
# ...          ...  ...    ...  ...  ...  ...   ...    ...    ...    ...   ...
# 2401  27-12-2023  754    729  517   55  108  5.04   7.51   2.19  32.20   0.5
# 2402  28-12-2023  693    689  456   83  102  5.00   7.51   2.21  32.05   0.5
# 2403  29-12-2023  749    724  496  106  107  4.95   7.51   2.22  32.05   0.5
# 2404  30-12-2023  703    698  523   84  103  5.03   7.58   2.23  32.18   0.5
# 2405  31-12-2023  712    703  519   65  104  4.94   7.53   2.21  32.12   0.5
#
# [2406 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le7 = LabelEncoder()
data['NH3'] = le7.fit_transform(data['NH3'])
data
# Out:
#             Date   CO  Ozone   NO  NO2  NOX  NH3    SO2  PM2.5   PM10   AQI
# 0     01-01-2024  114    136  495  267  558  330   6.60  31.00  59.00  59.0
# 1     02-01-2024   90    202  504  267  568  340   8.90  39.00  64.00  65.0
# 2     03-01-2024   67    385  504  258  547  330  10.30  34.00  61.00  61.0
# 3     04-01-2024  116    218  504  267  558  330   9.20  35.00  60.00  60.0
# 4     05-01-2024   56    269  495  258  540  330   8.40  21.00  37.00  37.0
# ...          ...  ...    ...  ...  ...  ...  ...    ...    ...    ...   ...
# 2401  27-12-2023  754    729  517   55  108  118   7.51   2.19  32.20   0.5
# 2402  28-12-2023  693    689  456   83  102  114   7.51   2.21  32.05   0.5
# 2403  29-12-2023  749    724  496  106  107  109   7.51   2.22  32.05   0.5
# 2404  30-12-2023  703    698  523   84  103  117   7.58   2.23  32.18   0.5
# 2405  31-12-2023  712    703  519   65  104  108   7.53   2.21  32.12   0.5
#
# [2406 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le8 = LabelEncoder()
data['PM2.5'] = le8.fit_transform(data['PM2.5'])
data
# Out:
#             Date   CO  Ozone   NO  NO2  NOX  NH3    SO2  PM2.5   PM10   AQI
# 0     01-01-2024  114    136  495  267  558  330   6.60    703  59.00  59.0
# 1     02-01-2024   90    202  504  267  568  340   8.90    733  64.00  65.0
# 2     03-01-2024   67    385  504  258  547  330  10.30    714  61.00  61.0
# 3     04-01-2024  116    218  504  267  558  330   9.20    720  60.00  60.0
# 4     05-01-2024   56    269  495  258  540  330   8.40    639  37.00  37.0
# ...          ...  ...    ...  ...  ...  ...  ...    ...    ...    ...   ...
# 2401  27-12-2023  754    729  517   55  108  118   7.51    135  32.20   0.5
# 2402  28-12-2023  693    689  456   83  102  114   7.51    137  32.05   0.5
# 2403  29-12-2023  749    724  496  106  107  109   7.51    138  32.05   0.5
# 2404  30-12-2023  703    698  523   84  103  117   7.58    139  32.18   0.5
# 2405  31-12-2023  712    703  519   65  104  108   7.53    137  32.12   0.5
#
# [2406 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le9 = LabelEncoder()
data['PM10'] = le9.fit_transform(data['PM10'])
data
# Out:
#             Date   CO  Ozone   NO  NO2  NOX  NH3    SO2  PM2.5  PM10   AQI
# 0     01-01-2024  114    136  495  267  558  330   6.60    703  1030  59.0
# 1     02-01-2024   90    202  504  267  568  340   8.90    733  1054  65.0
# 2     03-01-2024   67    385  504  258  547  330  10.30    714  1044  61.0
# 3     04-01-2024  116    218  504  267  558  330   9.20    720  1038  60.0
# 4     05-01-2024   56    269  495  258  540  330   8.40    639   907  37.0
# ...          ...  ...    ...  ...  ...  ...  ...    ...    ...   ...   ...
# 2401  27-12-2023  754    729  517   55  108  118   7.51    135   726   0.5
# 2402  28-12-2023  693    689  456   83  102  114   7.51    137   713   0.5
# 2403  29-12-2023  749    724  496  106  107  109   7.51    138   713   0.5
# 2404  30-12-2023  703    698  523   84  103  117   7.58    139   724   0.5
# 2405  31-12-2023  712    703  519   65  104  108   7.53    137   719   0.5
#
# [2406 rows x 11 columns]

# %%
x=data[['CO','Ozone','NO','NO2','NOX','NH3','SO2','PM2.5','PM10']]
y=data[['AQI']]
x
# Out:
#        CO  Ozone   NO  NO2  NOX  NH3    SO2  PM2.5  PM10
# 0     114    136  495  267  558  330   6.60    703  1030
# 1      90    202  504  267  568  340   8.90    733  1054
# 2      67    385  504  258  547  330  10.30    714  1044
# 3     116    218  504  267  558  330   9.20    720  1038
# 4      56    269  495  258  540  330   8.40    639   907
# ...   ...    ...  ...  ...  ...  ...    ...    ...   ...
# 2401  754    729  517   55  108  118   7.51    135   726
# 2402  693    689  456   83  102  114   7.51    137   713
# 2403  749    724  496  106  107  109   7.51    138   713
# 2404  703    698  523   84  103  117   7.58    139   724
# 2405  712    703  519   65  104  108   7.53    137   719
#
# [2406 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.2)
x_test
# Out:
#         CO  Ozone   NO  NO2  NOX  NH3  PM2.5  PM10
# 856     11    118   62  221  447    6    217    34
# 377    272    232  157   46  217  232     99   624
# 2247  1096   1187   91    0  204  458    302   444
# 1293  1348   1191  363   59  146  222    138   799
# 1040   890    728    4   11  422  618    458   355
# ...    ...    ...  ...  ...  ...  ...    ...   ...
# 164     41    784  311  307  579  476    651   991
# 1454  1367   1376  170   97  448  694    539   195
# 1300   752   1231  369   59  144  224    138   843
# 306    902    333  704   30  156  258    192   638
# 562    430    673  202  107  131  167    118   504
#
# [1924 rows x 8 columns]

# %%
from sklearn.linear_model import LinearRegression
le1=LinearRegression()
le1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Out:
# C:\Users\ashat\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[37.42610208]])

# %%
le1.predict(x_test)
# Out:
# array([[29.08292934],
#        [ 9.88335472],
#        [ 0.92996901],
#        ...,
#        [15.97456558],
#        [-6.84789356],
#        [20.03618609]], shape=(1924, 1))

# %%
import matplotlib.pyplot as plt
labels=['CO','Ozone','NO','NO2']
sizes=[40,30,20,10]
plt.pie(sizes,labels=labels)
plt.show()

# %%
import seaborn as sns
sns.histplot(data["AQI"])
# Out:
# <Axes: xlabel='AQI', ylabel='Count'>

# %%
from sklearn.tree import DecisionTreeRegressor
dt_regressor=DecisionTreeRegressor()
dt_regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
import pickle
file=open("traineddt.pkl","wb")
pickle.dump(dt_regressor,file)
file.close()

# %%
data=dt_regressor.predict(x_test)
data
# Out:
# array([0.  , 1.  , 1.  , ..., 1.  , 0.41, 0.5 ], shape=(1924,))

# %%
from sklearn.metrics import r2_score
y_pred = dt_regressor.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.6880948400756536

# %%
from sklearn.metrics import mean_squared_error
print("MSE", mean_squared_error(y_test, y_pred))
# Out:
# MSE 178.87557297297295

# %%
import numpy as np
print("RME",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RME 13.374437295563988

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=100)
model.fit(x_train,y_train)
# Out:
# C:\Users\ashat\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
data=model.predict(x_test)
data
# Out:
# array([0.    , 1.    , 0.9724, ..., 2.3794, 0.8989, 2.36  ], shape=(1924,))

# %%
from sklearn.metrics import r2_score
y_pred = model.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.8171926971353533

# %%
from sklearn.metrics import mean_squared_error
print("MSE", mean_squared_error(y_test, y_pred))
# Out:
# MSE 104.8387947525104

# %%
import numpy as np
print("RME",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RME 10.239081733852426

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_regressor = KNeighborsRegressor(n_neighbors=5)
knn_regressor.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
pre=knn_regressor.predict(x_test)
pre
# Out:
# array([[0.   ],
#        [1.   ],
#        [0.7  ],
#        ...,
#        [0.694],
#        [0.664],
#        [0.5  ]], shape=(1924, 1))

# %%
from sklearn.metrics import mean_squared_error
print("MSE", mean_squared_error(y_test, y_pred))
# Out:
# MSE 104.8387947525104

# %%
import numpy as np
print("RME",np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# RME 10.239081733852426

# %%
import matplotlib.pyplot as plt

# %%
categories=['Good','Unhealthy','Very Unhealthy','Hazardous']
values= [50,150,200,500]
plt.bar(categories,values)
plt.show()
